# %%
from sympy import *
import scipy
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Упражнение 1**
#
# ![image.png](attachment:image.png)

# %%
def p(point1, point2, type=0):
    match type:
        case 0:
            r = 0
            for k in range(0, len(point1)):
                if abs(point2[k] - point1[k]) > r:
                    r = abs(point2[k] - point1[k])
            return r
        case 1:
            r = 0
            for k in range(0, len(point1)):
                r += abs(point2[k] - point1[k])
            return r
        case 2:
            r = 0
            for k in range(0, len(point1)):
                r += (point2[k] - point1[k])**2
            return r**0.5


O = np.array([0,0])
A = np.array([3,4])
B = np.array([4,3])
for type in range(3):
    print(f"p{type}: OA = {p(O,A,type)}, OB = {p(O,B,type)}")
A = np.array([1,2,3,4])
B = np.array([7,3,4,200])
for type in range(3):
    print(f"p{type}: AB = {p(A,B,type)}")
# Out:
# p0: OA = 4, OB = 4
# p1: OA = 7, OB = 7
# p2: OA = 5.0, OB = 5.0
# p0: AB = 196
# p1: AB = 204
# p2: AB = 196.0969148150985

# %% [markdown]
# **Упражнение 2**
#
# ![image.png](attachment:4d39f953-0b18-4753-95c6-8d9c46a9fd1c.png)

# %%
def M(radius, type):
    x = np.array([])
    y = np.array([])
    O = np.array([0,0])
    for Xc in np.arange(-5*radius, 5*radius, 0.01):
        for Yc in np.arange(-5*radius, 5*radius, 0.01):
            if p(np.array([Xc,Yc]), O, type) <= radius:
                x = np.append(x, Xc)
                y = np.append(y, Yc)
    plt.scatter(x,y)
    plt.grid()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title("Круг типа " + str(type))
    plt.show()

M(1, 0)
M(1, 1)
M(1, 2)

# %% [markdown]
# **Упражнение 3**
#
# ![image.png](attachment:1429116a-a68e-4795-811f-2647bb5bd1d4.png)

# %%
x1 = 3
for i in range(9):
    x1 = np.tan(x1)
    print(x1)
# Out:
# -0.1425465430742778
# -0.14351994778492885
# -0.14451354178374737
# -0.14552803216462146
# -0.14656416116305784
# -0.14762270843290942
# -0.14870449350594378
# -0.14981037845185682
# -0.15094127075832087

# %% [markdown]
# **Упражнение 4**
#
# ![image.png](attachment:0d06d21f-592b-4f84-b803-056b9ef37ecc.png)
#
# ![image.png](attachment:d2618ae6-233a-4d1c-ba54-dae5bf7831a2.png)

# %%
def solve_fixed_point(func, alpha, x1, epsilon):
    x2 = func(x1)
    p_x1_x2 = abs(x2 - x1)

    numerator = np.log(epsilon * (1 - alpha)) - np.log(p_x1_x2)
    denominator = np.log(alpha)
    n_required = int(np.ceil(numerator / denominator))

    curr_x = x1
    print(f"x1 = {curr_x}")
    for i in range(1, n_required + 1):
        curr_x = func(curr_x)
        print(f"x{i+1} = {curr_x}")

    return curr_x

func = lambda x: np.exp(1 / (2 * x))

x = Symbol('x')
expr = exp(1 / (2 * x))
deriv = diff(expr, x)

x1 = 1.5
alpha = float(Abs(deriv.subs(x, x1)).evalf())

epsilon = 1e-4

solution = solve_fixed_point(func, alpha, x1, epsilon)

print(f"Решение: {solution}")
print(2 * solution * np.log(solution))
# Out:
# x1 = 1.5
# x2 = 1.3956124250860895
# x3 = 1.4308456817151025
# x4 = 1.418278331787257
# x5 = 1.4226767190712988
# x6 = 1.4211269558461999
# x7 = 1.4216717248106727
# x8 = 1.4214800697859904
# Решение: 1.4214800697859904
# 0.9998651903802142

# %% [markdown]
# **Упражнение 5**
#
# ![image.png](attachment:f25781ae-9194-48ca-b4f8-68e766fd7829.png)
#
# ![image.png](attachment:c909a182-a6de-4e39-9237-2e6b9783cac9.png)

# %%
import numpy as np

def solve_system_auto(A, B, epsilon=0.001):
    n = len(B)
    permuted_indices = []
    unused_rows = list(range(n))

    for i in range(n):
        best_row = max(unused_rows, key=lambda r: abs(A[r, i]))
        permuted_indices.append(best_row)
        unused_rows.remove(best_row)

    A = A[permuted_indices]
    B = B[permuted_indices]

    C = np.zeros((n, n))
    D = np.zeros(n)

    for i in range(n):
        diag_element = A[i, i]
        D[i] = B[i] / diag_element
        for j in range(n):
            if i == j:
                C[i, j] = 0
            else:
                C[i, j] = -A[i, j] / diag_element

    alpha = np.max(np.sum(np.abs(C), axis=1))
    if alpha >= 1:
        print("Условие сжатости не выполнено")
    else:
        print("Условие сжатости выполнено")

    X = B.copy()
    iterations = 0

    while True:
        X_new = C @ X + D
        iterations += 1

        error = np.linalg.norm(X_new - X, ord=np.inf)
        if error < epsilon:
            X = X_new
            break
        X = X_new

    return X, iterations, alpha

# بيانات вариант 8
A = np.array([
    [-9.26, -0.12, 1.23],
    [-0.45, 0.89, 8.12],
    [0.15, 5.62, -0.12]
])

B = np.array([8.42, -5.23, 6.54])

x, iter, alpha = solve_system_auto(A, B)

print(f"Решение X: {x}")
print(f"Количество итераций: {iter}")
print(f"Проверка (AX - B): {np.dot(A, x) - B}")
# Out:
# Условие сжатости выполнено
# Решение X: [-1.03475443  1.17360197 -0.83007635]
# Количество итераций: 5
# Проверка (AX - B): [-1.23906803e-07 -7.47270843e-05  3.90881459e-05]
