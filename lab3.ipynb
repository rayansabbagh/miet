# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import *

# %% [markdown]
# **Упражнение 1**
#
# ![image.png](attachment:image.png)

# %%
def show_seq(an, n0):
    n = np.arange(1, n0+1, 1)
    sums = np.zeros_like(n, np.float32)
    for i in range(0, n0):
        for j in range(i, n0):
            sums[j] += an(i+1)
    plt.plot(n, sums)
    plt.grid()
    plt.axis("equal")
    plt.xlabel("n")
    plt.ylabel("S")
    plt.show()

show_seq(lambda n: 1/(2**n), 10)

# %% [markdown]
# **Упражнение 2**
#
# ![image.png](attachment:4eb18f59-9010-4d7d-9a6e-8223636a09aa.png)

# %% [markdown]
#     Если 0<q<1(например, q=0.5): Ряд сходится. Сумма ряда S=q/(1-q) = 0.5/0.5 = 1​.
#
#     Если q=1: Ряд ∑1 расходится, так как Sn​=n→∞.
#
#     Если q>1(например, 2): Ряд расходится, так как общий член не стремится к нулю.

# %%
def show_seq(an, n0):
    n = np.arange(1, n0+1, 1)
    sums = np.zeros_like(n, np.float32)
    for i in range(0, n0):
        for j in range(i, n0):
            sums[j] += an(i+1)
    plt.plot(n, sums)
    plt.grid()
    plt.axis("equal")
    plt.xlabel("n")
    plt.ylabel("S")
    plt.show()

show_seq(lambda n: 0.5**n, 100)
show_seq(lambda n: 1**n, 100)
show_seq(lambda n: 2**n, 7)

# %% [markdown]
# **Упражнение 3**
#
# ![image.png](attachment:71290a25-528a-4eb6-97ea-37c48d5e23d2.png)

# %% [markdown]
# 1. α=1
# В общем виде для N=2k:
# $S_{2^k}​>1+\frac{k}{2}$​
#
# При k→∞ правая часть стремится к бесконечности. Следовательно, ряд расходится.
#
#
# 2. Случай α=0.5
#
# Здесь мы можем оценить частичную сумму $S_N$​ снизу:
# $S_N$​=$1+\frac{1}{\sqrt{2}}​+\frac{1}{\sqrt{3}}​+⋯+\frac{1}{\sqrt{N}}$​
#
# $S_N​>\frac{1}{\sqrt{N}}+\frac{1}{\sqrt{N}}+...​=\frac{N}{\sqrt{N}}​=\sqrt{N}$​
#
#
# При N→∞ значение $\sqrt{N}$​​→∞. Ряд расходится.
#
#
# 3. Случай α=2
#
# $\frac{1}{N^2}​<\frac{1}{N(N-1)}​​=\frac{1}{N-1}​-\frac{1}{N}​​$
#
# $S_N​<1+1−\frac{1}{N}​​=2−\frac{1}{N}​​<2$
#
# Так как последовательность частичных сумм $S_N$​ монотонно возрастает и ограничена сверху (числом 2), то по теореме Вейерштрасса она имеет конечный предел. Ряд сходится.

# %%
def show_seq(an, n0):
    n = np.arange(1, n0+1, 1)
    sums = np.zeros_like(n, np.float32)
    for i in range(0, n0):
        for j in range(i, n0):
            sums[j] += an(i+1)
    plt.plot(n, sums)
    plt.grid()
    plt.axis("equal")
    plt.xlabel("n")
    plt.ylabel("S")
    plt.show()

show_seq(lambda n: 1/np.sqrt(n), 100)
show_seq(lambda n: 1/n, 100)
show_seq(lambda n: 1/n**2, 100)

# %% [markdown]
# **Упражнение 4**
#
# ![image.png](attachment:77436bb9-000a-446c-bccb-ae0fbf50b970.png)

# %% [markdown]
# $\frac{1}{n}   | lim a_n = 0   |   Расходится$
#
# $\frac{1}{\sqrt{n}}   | lim a_n = 0   |   Расходится$
#
# $\frac{1}{\sqrt[3]{n}}   | lim a_n = 0   |   Расходится$
#
# $\frac{1}{\sqrt[4]{n}}   | lim a_n = 0   |   Расходится$

# %%
def show_seq(an, n0):
    n = np.arange(1, n0+1, 1)
    sums = np.zeros_like(n, np.float32)
    for i in range(0, n0):
        for j in range(i, n0):
            sums[j] += an(i+1)
    plt.plot(n, sums)
    plt.plot(n, an(n), "r")
    plt.grid()
    plt.axis("equal")
    plt.xlabel("n")
    plt.ylabel("S")
    plt.show()


show_seq(lambda n: 1/n, 50)
show_seq(lambda n: 1/np.sqrt(n), 50)
show_seq(lambda n: 1/n**(1/3), 50)
show_seq(lambda n: 1/n**(1/4), 50)

# %% [markdown]
# **Упражнение 5**
#
# ![image.png](attachment:2bcd2e05-e9fd-4f0f-ab19-4a5eead139de.png)

# %% [markdown]
# А)
# Ряд суммы будет расходится, например, $a_n = n; b_n = n$

# %%
def show_seq(an, n0):
    n = np.arange(1, n0+1, 1)
    sums = np.zeros_like(n, np.float32)
    for i in range(0, n0):
        for j in range(i, n0):
            sums[j] += an(i+1)
    plt.plot(n, sums)
    plt.grid()
    plt.axis("equal")
    plt.xlabel("n")
    plt.ylabel("S")
    plt.show()

show_seq(lambda n: n+n, 50)

# %% [markdown]
# Б)
# Ряд расходится, например, $a_n = n; b_n = \frac{1}{\sqrt{n}}$

# %%
def show_seq(an, n0):
    n = np.arange(1, n0+1, 1)
    sums = np.zeros_like(n, np.float32)
    for i in range(0, n0):
        for j in range(i, n0):
            sums[j] += an(i+1)
    plt.plot(n, sums)
    plt.grid()
    plt.axis("equal")
    plt.xlabel("n")
    plt.ylabel("S")
    plt.show()

show_seq(lambda n: n+1/np.sqrt(n), 50)

# %% [markdown]
# **Упражнение 6**
#
# ![image.png](attachment:a9d1364c-d00c-4227-836e-345a2eab63dc.png)

# %% [markdown]
# 1)
#
# $\sum_{n=1}^{\infty} \frac{1}{n\sqrt{n+1}\sqrt{n+2}} < \sum_{n=1}^{\infty} \frac{1}{n\sqrt{n}\sqrt{n}} = \sum_{n=1}^{\infty} \frac{1}{n^2}$ - сходится
#
# 2)
#
# $\sum_{n=1}^{\infty} \frac{2+\sin{n}}{\sqrt{n}} > \sum_{n=1}^{\infty} \frac{1}{\sqrt{n}} - расходится$

# %%
def show_seq(an, bn, n0):
    n = np.arange(1, n0+1, 1)
    sumsa = np.zeros_like(n, np.float32)
    sumsb = np.zeros_like(n, np.float32)
    for i in range(0, n0):
        for j in range(i, n0):
            sumsa[j] += an(i+1)
            sumsb[j] += bn(i+1)
    plt.plot(n, sumsa, "b", label="An")
    plt.plot(n, sumsb, "r", label="Bn")
    plt.grid()
    plt.axis("equal")
    plt.xlabel("n")
    plt.ylabel("S")
    plt.legend()
    plt.show()
    plt.plot(n, an(n), "g", label="an")
    plt.plot(n, bn(n), "y", label="bn")
    plt.grid()
    plt.axis("equal")
    plt.xlabel("n")
    plt.ylabel("An, Bn")
    plt.legend()
    plt.show()

print("А)")
show_seq(lambda n: 1/(n*np.sqrt(n+1)*np.sqrt(n+2)), lambda n: 1/n**2, 20)
print("Bn - сходится -> сходится и An")
print("Б)")
show_seq(lambda n: (2+np.sin(n))/(np.sqrt(n)), lambda n: 1/np.sqrt(n), 20)
print("Bn - расходится -> расходится и An")
# Out:
# А)
# Bn - сходится -> сходится и An
# Б)
# Bn - расходится -> расходится и An

# %% [markdown]
# **Упражнение 7**
#
# ![image.png](attachment:155c690d-a9b8-4f0a-90cf-a70be2b5540f.png)

# %%
def calcSum(func, eps):
    n = Symbol('n')
    a_n = sympify(func)
    
    ratio = a_n.subs(n, n + 1) / a_n
    n0 = 1
    while True:
        q_val = float(ratio.subs(n, n0))
        if q_val < 1:
            break
        n0 += 1
        
    q = float(ratio.subs(n, n0))
    a_func = lambdify(n, a_n, 'numpy')
    
    k = n0
    while True:
        remainder = a_func(k + 1) / (1 - q)
        if remainder < eps:
            break
        k += 1
        
    indices = np.arange(1, k + 1)
    total_sum = np.sum([float(a_func(i)) for i in indices])
    
    return total_sum

# %% [markdown]
# **Упражнение 8**
#
# ![image.png](attachment:ba7dacb6-677c-4404-800e-41e2573f9950.png)
#
# ![image.png](attachment:c1f8f931-df6b-463c-81c0-ecad300d34b1.png)

# %% [markdown]
# $\frac{a_{n+1}}{a_n} =
# \frac{\frac{\sqrt{n+2}}{2^{n+1}}}{\frac{\sqrt{n+1}}{2^n}} =
# \frac{\sqrt{n+2}\cdot 2^n}{\sqrt{n+1}\cdot 2^{n+1}} =
# \frac{\sqrt{n+2}}{2\sqrt{n+1}} =
# \frac{1}{2}\sqrt{\frac{n+2}{n+1}} < 1$
#
# $\frac{n+2}{n+1} < 2$
#
# $\sqrt{\frac{n+2}{n+1}} < \sqrt{2}$
#
# $\frac{1}{2}\sqrt{\frac{n+2}{n+1}} < 1$

# %%
print(calcSum('sqrt(n+1)/2.0**n', 0.001))
# Out:
# 1.6940196649288888

# %% [markdown]
# **Упражнение 9**
#
# ![image.png](attachment:642f76a7-1ebf-470c-94d0-55fa20f458a8.png)

# %%
def solve_series_task(formula_str, epsilon):
    n = Symbol('n')
    a_func = lambdify(n, sympify(formula_str), modules=['numpy'])
    
    k = 1
    while True:
        next_term = abs(a_func(k + 1))
        if next_term < epsilon:
            break
        k += 1

    indices = np.arange(1, k + 1)
    series_sum = np.sum([float(a_func(float(i))) for i in indices])
    
    return series_sum

# %% [markdown]
# **Упражнение 10**
#
# ![image.png](attachment:7fd8ce5d-371e-40e2-9d48-b4b8717645ba.png)
#
# ![image.png](attachment:22078dbc-6d3c-4761-82df-685714f6570d.png)

# %% [markdown]
# $|a_n| > |a_{n+1}|$
#
# $\frac{n}{2^n} > \frac{n+1}{2^{n+1}}$
#
# $\frac{n}{2^n} > \frac{n+1}{2\cdot 2^n}$
#
# $2n > n+1$
#
# $n > 1$
#
# $\lim_{n\to\infty}\frac{n}{2^n} = \left[\frac{\infty}{\infty}\right] =
# \lim_{n\to\infty}\frac{1}{\ln 2 \cdot 2^n} =
# \left[\frac{1}{\infty}\right] = 0$

# %%
print(solve_series_task('((-1)**(n-1))*n/(2**n)', 0.001))
# Out:
# 0.2227783203125
